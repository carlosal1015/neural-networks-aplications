# %% [markdown]
# # Software version
#
# - [`python`](https://archlinux.org/packages/core/x86_64/python)
# - [`python-matplotlib`](https://archlinux.org/packages/extra/x86_64/python-matplotlib)
# - [`python-numpy-mkl`](https://aur.archlinux.org/packages/python-numpy-mkl)
# - [`python-pandas`](https://archlinux.org/packages/extra/x86_64/python-pandas)
# - [`python-pysr`](https://aur.archlinux.org/packages/python-pysr)
# - [`python-pytorch-opt`](https://archlinux.org/packages/extra/x86_64/python-pytorch-opt)
# - [`python-torchviz-git`](https://aur.archlinux.org/packages/python-torchviz-git)
# - [`python-tqdm`](https://archlinux.org/packages/extra/any/python-tqdm)

# %%
import matplotlib
import numpy
import pandas
import pysr
import torch
import torchviz
import tqdm
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
print(f"Matplotlib version: {matplotlib.__version__}")
# Out:
# Matplotlib version: 3.10.8

# %%
numpy.show_config()
# Out:
# Build Dependencies:
#   blas:
#     detection method: pkgconfig
#     found: true
#     include directory: /opt/intel/oneapi/mkl/latest/include
#     lib directory: /opt/intel/oneapi/mkl/latest/lib
#     name: mkl-dynamic-lp64-seq
#     openblas configuration: unknown
#     pc file directory: /opt/intel/oneapi/mkl/2025.0/lib/pkgconfig
#     version: 2025.0.1
#   lapack:
#     detection method: pkgconfig
#     found: true
#     include directory: /opt/intel/oneapi/mkl/latest/include
#     lib directory: /opt/intel/oneapi/mkl/latest/lib
#     name: mkl-dynamic-lp64-seq
#     openblas configuration: unknown
#     pc file directory: /opt/intel/oneapi/mkl/2025.0/lib/pkgconfig
#     version: 2025.0.1
# Compilers:
#   c:
#     args: -march=x86-64, -mtune=generic, -O2, -pipe, -fno-plt, -fexceptions, -Wp,-D_FORTIFY_SOURCE=3,
#       -Wformat, -Werror=format-security, -fstack-clash-protection, -fcf-protection,
#       -fno-omit-frame-pointer, -mno-omit-leaf-frame-pointer, -flto=auto
# ...

# %%
print(f"Pandas version: {pandas.__version__}")
# Out:
# Pandas version: 2.3.1

# %%
print(f"PySR version {pysr.__version__}")
# Out:
# PySR version 1.5.9

# %%
print(torch.__config__.show())
# Out:
# PyTorch built with:
#   - GCC 15.2
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2025.0.1-Product Build 20241031 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.7.1 (Git Hash 8d263e693366ef8db40acc569cc7d8edf644556d)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
# ...

# %%
print(torchviz.__name__)  # https://stackoverflow.com/a/62458882
# Out:
# torchviz

# %%
print(f"tqdm version: {tqdm.__version__}")
# Out:
# tqdm version: 4.67.1
